# %% [markdown]
# # ELDEN, KELAN, and BLAINE's PANDAS PROJECT (Project 2)#
# Introduction to Statistical Analysis for Data Science
# In the world of data science, the ability to find meaningful relationships within large data sets is crucial. Statistical analysis provides the tools needed to explore, understand, and interpret complex data. By applying statistical methods, data scientists can uncover patterns, trends, and correlations that inform decision-making and drive innovation.
#
# How Data Scientists Use Statistical Analysis
# Data scientists employ a variety of statistical techniques to analyze data:
#
# Descriptive Statistics: These provide simple summaries about the sample and the measures. This includes mean, median, mode, standard deviation, and variance, helping to describe the basic features of the data.
#
# Inferential Statistics: These methods allow data scientists to make predictions or inferences about a population based on a sample of data. Techniques include hypothesis testing, confidence intervals, and regression analysis.
#
# Correlation Analysis: This assesses the relationship between two variables. By calculating correlation coefficients, data scientists can determine the strength and direction of the relationship.
#
# Regression Analysis: This technique models the relationship between a dependent variable and one or more independent variables. Linear regression, logistic regression, and polynomial regression are commonly used to predict outcomes and understand relationships.
#
# Exploratory Data Analysis (EDA): EDA involves visualizing data through graphs, charts, and other tools to identify patterns, anomalies, and insights. This step often precedes formal modeling and analysis.
#
# Relevance to Physics
# Statistical analysis is not limited to traditional data science fields; it is also highly relevant to physics. In physics, statistical methods are used to:
#
# Analyze Experimental Data: Physicists collect data from experiments and use statistical analysis to understand the results, identify trends, and validate hypotheses.
# Model Physical Phenomena: Many physical systems are complex and involve multiple variables. Statistical models help in understanding and predicting these systems' behavior.
# Error Analysis: Statistical techniques are essential for quantifying uncertainties and errors in experimental measurements, leading to more accurate and reliable conclusions.
# Assignment: Importing and Analyzing Data Sets from Kaggle using Pandas
# For this assignment, you will work in groups of 2-3 students to use the pandas module in Python to import and analyze data sets from Kaggle. Pandas is a powerful tool for data manipulation and analysis, providing data structures and functions needed to work with structured data seamlessly.
#
# Objectives
# Import Data: Learn to import data sets from Kaggle into Python using pandas.
# Clean and Prepare Data: Understand how to clean and prepare data for analysis, handling missing values, and converting data types.
# Descriptive Statistics: Calculate and interpret basic descriptive statistics for the data set.
# Exploratory Data Analysis: Perform exploratory data analysis using visualizations to identify patterns and relationships.
# Correlation and Regression Analysis: Conduct correlation and regression analysis to find and interpret relationships between variables.
# Deliverables (Per Group)
# Python Script: A well-documented Python script that imports the data set, cleans it, and performs statistical analysis.
# Brief Report: A brief report (1-2 pages) summarizing the dataset, the analysis performed, and the key insights obtained.
# Presentation: A short (5-10 minute) presentation to share your key findings with the class.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

data = pd.read_csv("Titanic-Dataset.csv")
print(data)
surviveData = data[data["Survived"] == 1]
deadData = data[data["Survived"] == 0]
age = data[data["Age"] >= 0]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
plt.hist(data["Age"], bins = 50)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(data["Pclass"], data["Fare"])
plt.title("Class of Passengers vs their Fare")
plt.xlabel("Class")
plt.ylabel("Fare")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.hist(deadData["Age"], bins = 50, label = "Dead")
plt.hist(surviveData["Age"], bins = 50, label = "Survived")
plt.xlabel("Age of People")
plt.ylabel("Number of People Survived")
plt.title("Age vs People Survived")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
### Percentage of people who died vs Age ###

total = np.array([data[(data["Age"] < 10) & (data["Age"] >= 0)].shape[0],
data[(data["Age"] < 20) & (data["Age"] >= 10)].shape[0],
data[(data["Age"] < 30) & (data["Age"] >= 20)].shape[0],
data[(data["Age"] < 40) & (data["Age"] >= 30)].shape[0],
data[(data["Age"] < 50) & (data["Age"] >= 40)].shape[0],
data[(data["Age"] < 60) & (data["Age"] >= 50)].shape[0],
data[(data["Age"] < 70)& (data["Age"] >= 60)].shape[0],
data[(data["Age"] < 80) & (data["Age"] >= 70)].shape[0]
])
survive = np.array([
data[(data["Age"] < 10) & (data["Age"] >= 0) & (data["Survived"] == 1)].shape[0],
data[(data["Age"] < 20) & (data["Age"] >= 10)& (data["Survived"] == 1)].shape[0],
data[(data["Age"] < 30) & (data["Age"] >= 20)& (data["Survived"] == 1)].shape[0],
data[(data["Age"] < 40) & (data["Age"] >= 30)& (data["Survived"] == 1)].shape[0],
data[(data["Age"] < 50) & (data["Age"] >= 40)& (data["Survived"] == 1)].shape[0],
data[(data["Age"] < 60) & (data["Age"] >= 50)& (data["Survived"] == 1)].shape[0],
data[(data["Age"] < 70) & (data["Age"] >= 60)& (data["Survived"] == 1)].shape[0],
data[(data["Age"] < 80) & (data["Age"] >= 70)& (data["Survived"] == 1)].shape[0]
])

plt.bar([10,20,30,40,50,60,70,80], ((survive / total) * 100),width = 8)
plt.xlabel("Age Bins")
plt.ylabel("Percentage of Survivors")
plt.title("Percentage of people who died vs Age")
plt.show()

# %%
##Percent Survived per Class
clas = np.array([
    data[(data["Pclass"] == 1) & (data["Survived"] == 1)].shape[0],
    data[(data["Pclass"] == 2) & (data["Survived"] == 1)].shape[0],
    data[(data["Pclass"] == 3) & (data["Survived"] == 1)].shape[0]
])

totalc = np.array([
    data[(data["Pclass"] == 1)].shape[0],
    data[(data["Pclass"] == 1)].shape[0],
    data[(data["Pclass"] == 1)].shape[0]
])

print(clas)
print(totalc)
plt.bar([1,2,3], (clas / totalc) * 100 ,width = 0.8)
plt.xlabel("Class")
plt.ylabel("Percentage of Survivors")
plt.title("Percentage of people who died vs Class")
plt.show()
# Out:
# [136  87 119]
# [216 216 216]
